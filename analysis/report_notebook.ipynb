# %% [markdown]
# # Potentially inappropriate prescribing of DOACs to people with mechanical heart valves: a federated analysis of 57.9 million patients’ primary care records in situ using OpenSAFELY

# %% [markdown]
# In the early phase of the COVID-19 pandemic, NHS England recommended that, where appropriate, people prescribed warfarin should be switched to direct oral anticoagulants (DOACs) which require less frequent blood testing [[1](#reference_1)]. As warfarin requires frequent blood tests, this guidance was intended to support the reduction of pressures being experienced by the NHS and we have previously shown the increased switching of anticoagulants to DOACs following this guidance [[2](#reference_2)]. The use of DOACs in people with mechanical heart valves is not recommended and was explicitly advised against in the guidance issued by national bodies during the switching programme [[1](#reference_1),[3](#reference_3)]. Despite this, NHS England received anecdotal reports of those with mechanical heart valves being prescribed a DOAC as a result of switching anticoagulation during the pandemic. This report describes the monthly use of DOACs in people with mechanical heart valves throughout the COVID-19 pandemic in a federated analysis of 57.9 million people.

# %% [markdown]
# ## Monthly Count
# The monthly number of DOAC prescriptions in people with a record of a mechanical valve.

# %%
from IPython.display import Image
Image("../released_outputs/count.jpeg")

# %% [markdown]
# ## Monthly Rate
# The monthly rate of DOAC prescribing per 1000 people with a record of a mechanical valve.

# %%
Image("../released_outputs/rate.jpeg")

# %% [markdown]
# ### References
# 1.	Clinical guide for the management of anticoagulant services during the coronavirus pandemic. NHS England https://www.nice.org.uk/Media/Default/About/COVID-19/Specialty-guides/specialty-guide-anticoagulant-services-and-coronavirus.pdf. <a id="reference_1"></a>
# 2.	Curtis, H. J. et al. OpenSAFELY: impact of national guidance on switching from warfarin to direct oral anticoagulants (DOACs) in early phase of COVID-19 pandemic in England. doi:10.1101/2020.12.03.20243535. <a id="reference_2"></a>
# 3.	2017 ESC/EACTS Guidelines for the management of valvular heart disease. Eur. Heart J. 39, 1980 (2017). <a id="reference_3"></a>
